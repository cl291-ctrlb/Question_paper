# %%
#;For the given data plot scatter plot using matlplotlib to show relationship between math and scienc scores and lablel axes and given appropriate title
import matplotlib.pyplot as plt

# %%
Math_scores = [78,85,90,72,88,95,80,76,89,92] #dataset 
Science_scores = [82,87,91,74,85,97,78,79,90,94]
plt.scatter(Math_scores,Science_scores,color='pink',marker='o') #plot scatter plot
plt.xlabel("Math scores") #add labels
plt.ylabel("Science scores")
plt.title("gaddit vs vigyan")
#plt.show() difference
plt.show()
